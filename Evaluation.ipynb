# %% [markdown]
# # Evaluation Results

# %% [markdown]
# ## I have not displayed entire rendered video for segmentation rather than just displaying some of the particular frame, but to produce the video anyone can iterate through all the images to get the complete video.

# %% [markdown]
# ## Stage - 0 (DAVIS17)

# %%
# !ls
# Out:
# Evaluation.ipynb  pyptoject.toml  README.md	    src
# Makefile	  pytest.ini	  requirements.txt

# %%
# !ls src/data_domain/validation/d17/
# Out:
# bike-packing	dance-twirl	india		paragliding-launch
# blackswan	dog		judo		parkour
# bmx-trees	dogs-jump	kite-surf	pigs
# breakdance	drift-chicane	lab-coat	scooter-black
# camel		drift-straight	libby		shooting
# car-roundabout	goat		loading		soapbox
# car-shadow	gold-fish	mbike-trick
# cows		horsejump-high	motocross-jump

# %%
# !ls src/data_domain/validation/d17/bike-packing/
# Out:
# 00000.png  00010.png  00020.png  00030.png  00040.png  00050.png  00060.png
# 00001.png  00011.png  00021.png  00031.png  00041.png  00051.png  00061.png
# 00002.png  00012.png  00022.png  00032.png  00042.png  00052.png  00062.png
# 00003.png  00013.png  00023.png  00033.png  00043.png  00053.png  00063.png
# 00004.png  00014.png  00024.png  00034.png  00044.png  00054.png  00064.png
# 00005.png  00015.png  00025.png  00035.png  00045.png  00055.png  00065.png
# 00006.png  00016.png  00026.png  00036.png  00046.png  00056.png  00066.png
# 00007.png  00017.png  00027.png  00037.png  00047.png  00057.png  00067.png
# 00008.png  00018.png  00028.png  00038.png  00048.png  00058.png  00068.png
# 00009.png  00019.png  00029.png  00039.png  00049.png  00059.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def get_image(path):
    img = plt.imread(path)
    imgplot = plt.imshow(img)
    plt.show()

# %%
get_image('src/data_domain/validation/d17/bike-packing/00000.png')

# %% [markdown]
# ### Below images are the part of same video at 19th and 20th frames.

# %%
get_image('src/data_domain/validation/d17/india/00019.png')

# %%
get_image('src/data_domain/validation/d17/india/00020.png')

# %% [markdown]
# ## Stage - 0 (DAVIS16)

# %%
# !ls src/data_domain/validation/d16/
# Out:
# blackswan   car-roundabout  dog		    horsejump-high  paragliding-launch
# bmx-trees   car-shadow	    drift-chicane   kite-surf	    parkour
# breakdance  cows	    drift-straight  libby	    scooter-black
# camel	    dance-twirl     goat	    motocross-jump  soapbox

# %%
get_image('src/data_domain/validation/d16/dog/00000.png')

# %%
get_image('src/data_domain/validation/d16/cows/00020.png')

# %%
get_image('src/data_domain/validation/d16/cows/00021.png')

# %% [markdown]
# ## Stage - 0 (Youtube 2018)

# %%
# !ls src/data_domain/validation/y18/Annotations/00f88c4f0a/
# Out:
# 00010.png  00035.png  00060.png  00085.png  00110.png  00135.png  00160.png
# 00015.png  00040.png  00065.png  00090.png  00115.png  00140.png  00165.png
# 00020.png  00045.png  00070.png  00095.png  00120.png  00145.png  00170.png
# 00025.png  00050.png  00075.png  00100.png  00125.png  00150.png  00175.png
# 00030.png  00055.png  00080.png  00105.png  00130.png  00155.png

# %%
get_image('src/data_domain/validation/y18/Annotations/00f88c4f0a/00150.png')

# %% [markdown]
# ## View Stage - 0 Log - https://drive.google.com/drive/folders/1gqBFf7IMIa17CXXn6WHUuxBj_mATxcdW?usp=sharing

# %% [markdown]
# ## Stage - 2 (Davis2016 and 2017)

# %%
# !ls src/data_domain/validation/stage_two/d17/
# Out:
# bike-packing	dance-twirl	india		paragliding-launch
# blackswan	dog		judo		parkour
# bmx-trees	dogs-jump	kite-surf	pigs
# breakdance	drift-chicane	lab-coat	scooter-black
# camel		drift-straight	libby		shooting
# car-roundabout	goat		loading		soapbox
# car-shadow	gold-fish	mbike-trick
# cows		horsejump-high	motocross-jump

# %%
# !ls src/data_domain/validation/stage_two/d16/
# Out:
# blackswan   car-roundabout  dog		    horsejump-high  paragliding-launch
# bmx-trees   car-shadow	    drift-chicane   kite-surf	    parkour
# breakdance  cows	    drift-straight  libby	    scooter-black
# camel	    dance-twirl     goat	    motocross-jump  soapbox

# %%
get_image('src/data_domain/validation/stage_two/d17/pigs/00015.png')

# %%
get_image('src/data_domain/validation/stage_two/d16/camel/00012.png')

# %% [markdown]
# ## Stage - 2 (Youtube 2018 and 2019)

# %%
# !ls src/data_domain/validation/stage_two/y18/Annotations/03664dc880/
# Out:
# 00000.png  00015.png  00030.png  00045.png  00060.png  00075.png  00090.png
# 00005.png  00020.png  00035.png  00050.png  00065.png  00080.png
# 00010.png  00025.png  00040.png  00055.png  00070.png  00085.png

# %%
# !ls src/data_domain/validation/stage_two/y18/Annotations/4bef684040/
# Out:
# 00000.png  00025.png  00050.png  00075.png  00100.png  00125.png
# 00005.png  00030.png  00055.png  00080.png  00105.png  00130.png
# 00010.png  00035.png  00060.png  00085.png  00110.png  00135.png
# 00015.png  00040.png  00065.png  00090.png  00115.png  00140.png
# 00020.png  00045.png  00070.png  00095.png  00120.png

# %%
get_image('src/data_domain/validation/stage_two/y18/Annotations/03664dc880/00005.png')

# %%
get_image('src/data_domain/validation/stage_two/y18/Annotations/4bef684040/00015.png')

# %% [markdown]
# ## View Stage - 2 Log - https://drive.google.com/drive/folders/13jL2YklqopEJJtzH7ZDY00AcLsrqXCFH?usp=sharing

# %% [markdown]
# ## Stage - 2 MultiScale Evaluation - Youtube 2018

# %%
# !ls src/data_domain/validation/stage_two/y18_ms/720p/Annotations/0062f687f1/
# Out:
# 00000.png  00015.png  00030.png  00045.png  00060.png  00075.png  00090.png
# 00005.png  00020.png  00035.png  00050.png  00065.png  00080.png
# 00010.png  00025.png  00040.png  00055.png  00070.png  00085.png

# %%
# !ls src/data_domain/validation/stage_two/y18_ms/720p_flip/Annotations/4e132f2efb/
# Out:
# 00170.png  00185.png  00200.png  00215.png  00230.png  00245.png  00260.png
# 00175.png  00190.png  00205.png  00220.png  00235.png  00250.png  00265.png
# 00180.png  00195.png  00210.png  00225.png  00240.png  00255.png

# %%
get_image('src/data_domain/validation/stage_two/y18_ms/720p/Annotations/0062f687f1/00015.png')

# %%
get_image('src/data_domain/validation/stage_two/y18_ms/720p_flip/Annotations/4e132f2efb/00170.png')

# %%
# !ls src/data_domain/validation/stage_two/y18_ms/y18_ms_merged/Annotations/77df215672/
# Out:
# 00080.png  00095.png  00110.png  00125.png  00140.png  00155.png  00170.png
# 00085.png  00100.png  00115.png  00130.png  00145.png  00160.png  00175.png
# 00090.png  00105.png  00120.png  00135.png  00150.png  00165.png

# %%
get_image('src/data_domain/validation/stage_two/y18_ms/y18_ms_merged/Annotations/77df215672//00170.png')

# %% [markdown]
# ## View Stage - 2 MultiScale Log - https://drive.google.com/drive/folders/1CT6BcM5ay-31mrMCzu6kTZQcpVxBvAXZ?usp=sharing
